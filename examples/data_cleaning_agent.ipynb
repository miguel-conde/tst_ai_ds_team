# %% [markdown]
# # How to Automate Data Cleaning with AI <a id="make-a-data-cleaning-agent"></a>
#
# In this tutorial, you will learn how to automate data cleaning with AI. It can automatically:
#
# - detect and fix common data cleaning issues
# - missing values
# - duplicate rows
# - inconsistent data types.
#
# By using this AI agent, you can save time and effort on data cleaning, allowing you to focus on more important tasks.
#
# ### Want To Become A Full-Stack Generative AI Data Scientist?
#
# ![Generative AI Data Scientist](../img/become_a_generative_ai_data_scientist.jpg)
#
# I teach Generative AI Data Science to help you build AI-powered data science apps. [**Register for my next Generative AI for Data Scientists workshop here.**](https://learn.business-science.io/ai-register)

# %% [markdown]
# # Table of Contents
#
# 1. [Make A Data Cleaning Agent](#make-a-data-cleaning-agent)
# 2. [Load Libraries](#load-libraries)
# 3. [Setup AI and Logging](#setup-ai-and-logging)
# 4. [Load a Dataset](#load-a-dataset)
# 5. [Create The Agent](#create-the-agent)
# 6. [Response](#response)
# 7. [The cleaning recipe](#the-cleaning-recipe)
# 8. [Data Cleaner Function](#data-cleaner-function)
# 9. [Cleaned Data As Pandas Data Frame](#cleaned-data-as-pandas-data-frame)
# 10. [Free Generative AI Data Science Workshop](#free-generative-ai-data-science-workshop)

# %% [markdown]
# ### Load Libraries <a id="load-libraries"></a>

# %%
# * Libraries

from langchain_openai import ChatOpenAI
import os
import yaml
import pandas as pd
from pprint import pprint

from ai_data_science_team.agents import DataCleaningAgent

# %% [markdown]
# ### Setup AI and Logging <a id="setup-ai-and-logging"></a>
#
# This section of code sets up the LLM inputs and the logging information. Logging is used to store AI-generated code and files during the AI Data Science Teams processing of files.
#
# *Important Note:* This example uses OpenAI's API. But any LLM can be used such as Anthropic or local LLMs with Ollama.

# %%
# * Setup

MODEL    = "gpt-4o-mini"
LOG      = True
LOG_PATH = os.path.join(os.getcwd(), "logs/")

# os.environ["OPENAI_API_KEY"] = yaml.safe_load(open('../credentials.yml'))['openai']

llm = ChatOpenAI(model = MODEL)

llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x791c8a44e270>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x791c8a44fe60>, root_client=<openai.OpenAI object at 0x791c8abc4650>, root_async_client=<openai.AsyncOpenAI object at 0x791c8a44e2d0>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %% [markdown]
# ### Load a Dataset <a id="load-a-dataset"></a>
#
# Next, let's load a customer churn data set that we will clean up.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/business-science/ai-data-science-team/refs/heads/master/data/churn_data.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# ### Create The Agent <a id="create-the-agent"></a>
#
# Run this code to create an agent with `make_data_cleaning_agent()`.

# %%
data_cleaning_agent = DataCleaningAgent(
    model = llm, 
    log=LOG, 
    log_path=LOG_PATH
)

data_cleaning_agent

# %% [markdown]
# This creates an `app`, which is a langgraph agent with the main inputs:
#
# - **user_instructions**: The data cleaning agent will use these comments to modify the "standard recipe"
#   - Standard Recipe: The standard cleaning recipe which includes removing columns with more than 40% missing values, imputing missing values using mean (numeric) or mode (categorical), removing duplicate rows, and removing outliers.
# - **data_raw**: The raw data to be cleaned
# - **max_retries**: Used to limit the number of attempts to fix the python code generated by the agent. Set this to 3 to limit to 3 attempts.
# - **retry_count**: Set this to 0.

# %%
data_cleaning_agent.invoke_agent(
    data_raw=df,
    user_instructions="Don't remove outliers when cleaning the data.",
    max_retries=3,
    retry_count=0
)
# Out:
# ---DATA CLEANING AGENT----
#     * RECOMMEND CLEANING STEPS
#     * CREATE DATA CLEANER CODE
#       File saved to: /home/miguel-conde/Documents/tst_ai_ds_team/examples/logs/data_cleaner.py
#     * EXECUTING AGENT CODE
#     * REPORT AGENT OUTPUTS

# %% [markdown]
# ### Response <a id="response"></a>
#
# The response produced contains everything we need to understand the data cleaning decisions made and get the cleaned dataset.

# %%
response = data_cleaning_agent.get_response()

list(response.keys())
# Out:
# ['messages',
#  'user_instructions',
#  'recommended_steps',
#  'data_raw',
#  'data_cleaned',
#  'all_datasets_summary',
#  'data_cleaner_function',
#  'data_cleaner_function_path',
#  'data_cleaner_file_name',
#  'data_cleaner_function_name',
#  'data_cleaner_error',
#  'max_retries',
#  'retry_count']

# %% [markdown]
# #### Cleaned Data As Pandas Data Frame <a id="cleaned-data-as-pandas-data-frame"></a>

# %% [markdown]
# Use the `get_data_cleaned()` method to get the cleaned data as a pandas data frame.

# %%
data_cleaning_agent.get_data_cleaned()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7043 rows x 21 columns]

# %% [markdown]
# #### Data Cleaner Function <a id="data-cleaner-function"></a>

# %% [markdown]
# We can use the `get_data_cleaner_function()` method to get the data cleaner function pipeline.
#
# - In Jupyter Notebooks, setting `markdown=True` will return the function as markdown code.
# - In Streamlit apps, it's recommended to set `markdown=False`.

# %%
data_cleaning_agent.get_data_cleaner_function(markdown=True)
# Out:
# ```python
# # Disclaimer: This function was generated by AI. Please review before using.
# # Agent Name: data_cleaning_agent
# # Time Created: 2025-02-08 08:05:03
#
# def data_cleaner(data_raw):
#     import pandas as pd
#     import numpy as np
#
#
#     # Step 1: Check for Missing Values
#     # No columns are removed because there are no missing values.
#
#     # Step 2: Convert Data Types
#     # Convert the TotalCharges column from object to float64
#     data_raw['TotalCharges'] = pd.to_numeric(data_raw['TotalCharges'], errors='coerce')
#     # Comment: This step converts TotalCharges to a numeric type for better analysis.
#
#     # Step 3: Remove Duplicate Rows
#     data_raw.drop_duplicates(inplace=True)
#     # Comment: This ensures that each customer record is unique.
#
#     # Step 4: Impute Missing Values (if applicable)
#     # No missing value imputation is performed as all values are present.
#
#     # Step 5: Remove Rows with Missing Values (if applicable)
#     # No rows are removed since there are no missing values.
#
#     # Step 6: Check for Outliers
#     # Note: Outliers are not removed, but could be flagged for further analysis.
#
#     # Step 7: Analyze Data for Additional Cleaning Needs
#     # We will review unique value counts in categorical columns later if needed.
#
#     # Step 8: Final Review and Export Data
#     # Confirm transformations are documented.
#
#     # Return the cleaned data
#     return data_raw
# ```

# %% [markdown]
# #### Recommended Steps
#
# To get the recommended steps during the data analysis (prior to coding), run the `get_recommended_steps()` method.

# %%
data_cleaning_agent.get_recommended_cleaning_steps(markdown=True)
# Out:
# # Recommended Data Cleaning Steps:
# Here are the recommended steps to clean and preprocess the dataset, tailored specifically to the characteristics of the provided data and in line with the user instructions:
#
# 1. **Check for Missing Values**:
#    - Since all columns in the dataset have 0% missing values, no columns need to be removed based on the missing value criterion.
#    - **Comment**: No columns are removed because there are no missing values.
#
# 2. **Convert Data Types**:
#    - Convert the `TotalCharges` column from `object` to `float64`. This is necessary since the column contains numeric values represented as strings.
#    - **Code Snippet**: `df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')`
#    - **Comment**: This step converts `TotalCharges` to a numeric type for better analysis.
#
# 3. **Remove Duplicate Rows**:
#    - Check for duplicates in the dataset and remove them if any are found.
#    - **Code Snippet**: `df.drop_duplicates(inplace=True)`
#    - **Comment**: This ensures that each customer record is unique.
#
# 4. **Impute Missing Values** (if applicable):
#    - There are no missing values in numeric or categorical columns, so imputation is not needed.
#    - **Comment**: No missing value imputation is performed as all values are present.
#
# 5. **Remove Rows with Missing Values** (if applicable):
#    - Again, since there are no missing values, this step is not necessary.
#    - **Comment**: No rows are removed since there are no missing values.
#
# 6. **Check for Outliers**:
#    - Although user instruction specifies not to remove outliers, it is still useful to identify and flag them for potential analysis and reporting.
#    - **Comment**: Analysis of outliers can help in determining customer behavior.
#
# 7. **Analyze Data for Additional Cleaning Needs**:
#    - Review the unique value counts in categorical columns to ensure they are suitable for analysis. Determine if any categorical columns need encoding for machine learning purposes.
#    - **Comment**: Consider one-hot encoding or label encoding for categorical columns before model training.
#
# 8. **Final Review and Export Data**:
#    - Review cleaned dataset to ensure all transformations have been applied correctly. No data saving steps will be executed as per user instructions.
#    - **Comment**: Confirm all transformations are appropriately documented.
#
# By following these steps, you can ensure that the data is clean, consistent, and ready for further analysis or modeling.

# %% [markdown]
# ### Want To Become A Full-Stack Generative AI Data Scientist?
#
# ![Generative AI Data Scientist](../img/become_a_generative_ai_data_scientist.jpg)
#
# I teach Generative AI Data Science to help you build AI-powered data science apps. [**Register for my next Generative AI for Data Scientists workshop here.**](https://learn.business-science.io/ai-register)
